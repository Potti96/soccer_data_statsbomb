# %% [markdown]
# # load packages

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## set directory

# %%
os.getcwd()
# Out:
# 'c:\\github\\soccer_data_statsbomb\\script'

# %%
os.chdir('c:\\github\\soccer_data_statsbomb')

# %% [markdown]
# # load data

# %% [markdown]
# ## competitions

# %%
df_competitons = pd.read_json('data\\competitions.json')
df_competitons
# Out:
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 70              35         75         Europe      UEFA Europa League
# 71              53        315         Europe       UEFA Women's Euro
# 72              53        106         Europe       UEFA Women's Euro
# 73              72        107  International       Women's World Cup
# 74              72         30  International       Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# ...

# %%
df_competitons.shape
# Out:
# (75, 12)

# %%
df_competitons.columns
# Out:
# Index(['competition_id', 'season_id', 'country_name', 'competition_name',
#        'competition_gender', 'competition_youth', 'competition_international',
#        'season_name', 'match_updated', 'match_updated_360',
#        'match_available_360', 'match_available'],
#       dtype='object')

# %%
df_competitons.dtypes
# Out:
# competition_id                int64
# season_id                     int64
# country_name                 object
# competition_name             object
# competition_gender           object
# competition_youth              bool
# competition_international      bool
# season_name                  object
# match_updated                object
# match_updated_360            object
# match_available_360          object
# match_available              object
# dtype: object

# %%
df_competitons.describe()
# Out:
#        competition_id   season_id
# count       75.000000   75.000000
# mean        83.106667   90.066667
# std        258.209300   97.953151
# min          2.000000    1.000000
# 25%         11.000000   25.500000
# 50%         16.000000   42.000000
# 75%         43.000000  107.000000
# max       1470.000000  315.000000

# %%
df_competitons.isnull().sum()
# Out:
# competition_id                0
# season_id                     0
# country_name                  0
# competition_name              0
# competition_gender            0
# competition_youth             0
# competition_international     0
# season_name                   0
# match_updated                 0
# match_updated_360            18
# match_available_360          64
# match_available               0
# dtype: int64

# %% [markdown]
# ## matches

# %%
df_match_2_27 = pd.read_json('data\\matches\\2\\27.json')
df_match_2_27.head(1)
# Out:
#    match_id  match_date      kick_off  \
# 0   3754058  2016-01-02  16:00:00.000
#
#                                          competition  \
# 0  {'competition_id': 2, 'country_name': 'England...
#
#                                           season  \
# 0  {'season_id': 27, 'season_name': '2015/2016'}
#
#                                            home_team  \
# 0  {'home_team_id': 22, 'home_team_name': 'Leices...
#
#                                            away_team  home_score  away_score  \
# 0  {'away_team_id': 28, 'away_team_name': 'AFC Bo...           0           0
#
#   match_status match_status_360                last_updated  \
# 0    available       processing  2021-10-29T23:44:19.940296
#
#           last_updated_360                                           metadata  \
# 0  2021-06-12T16:17:31.694  {'data_version': '1.1.0', 'shot_fidelity_versi...
#
#    match_week                    competition_stage  \
# 0          20  {'id': 1, 'name': 'Regular Season'}
#
# ...

# %%
df_match_2_27.shape
# Out:
# (380, 18)

# %%
df_match_2_27.dtypes
# Out:
# match_id              int64
# match_date           object
# kick_off             object
# competition          object
# season               object
# home_team            object
# away_team            object
# home_score            int64
# away_score            int64
# match_status         object
# match_status_360     object
# last_updated         object
# last_updated_360     object
# metadata             object
# match_week            int64
# competition_stage    object
# stadium              object
# referee              object
# dtype: object

# %%
df_match_2_27.describe()
# Out:
#            match_id  home_score  away_score  match_week
# count  3.800000e+02  380.000000  380.000000  380.000000
# mean   3.754162e+06    1.492105    1.207895   19.500000
# std    1.098408e+02    1.259242    1.146955   10.980313
# min    3.753972e+06    0.000000    0.000000    1.000000
# 25%    3.754067e+06    1.000000    0.000000   10.000000
# 50%    3.754162e+06    1.000000    1.000000   19.500000
# 75%    3.754256e+06    2.000000    2.000000   29.000000
# max    3.754351e+06    6.000000    6.000000   38.000000

# %%
df_match_2_27.isnull().sum()
# Out:
# match_id             0
# match_date           0
# kick_off             0
# competition          0
# season               0
# home_team            0
# away_team            0
# home_score           0
# away_score           0
# match_status         0
# match_status_360     0
# last_updated         0
# last_updated_360     0
# metadata             0
# match_week           0
# competition_stage    0
# stadium              0
# referee              0
# dtype: int64

# %% [markdown]
# ## three-sixty

# %%
pd.read_json('data\\three-sixty\\3788741.json')
# Out:
#                                 event_uuid  \
# 0     5c888f58-fe77-459b-ab3b-a2fa5fb8ab16
# 1     776e11e0-9e85-4226-9f9e-edefa3685288
# 2     bea4235d-7e40-461c-bb82-6d473f5bb324
# 3     84b9b798-0fbe-45bc-a4bf-3621959f29ce
# 4     6e2955cf-ad4f-4096-a4dd-053173a3802b
# ...                                    ...
# 3365  3a176721-5ca0-43d8-813c-482a2688c932
# 3366  98eaff6a-811b-4101-80ba-aa4bf7797d1f
# 3367  87f19c86-543d-4a7a-93bb-b576fe9be63d
# 3368  9a782a08-27d0-4d77-908f-fdfde7e5f3a4
# 3369  feb59f80-cefc-4dea-85ea-dfb9e4efb799
#
#                                            visible_area  \
# 0     [0.0, 27.7649873094419, 19.2332231959735, 17.3...
# 1     [34.5953633899854, 77.2328373069048, 6.5972315...
# 2     [34.5953633899854, 77.2328373069048, 6.5972315...
# 3     [35.4292984462803, 78.5704958529984, 7.7187164...
# 4     [19.7831665231312, 80.0, 41.3426126170851, 0.0...
# ...                                                 ...
# ...
